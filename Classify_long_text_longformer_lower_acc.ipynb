# %% [markdown]
# <a href="https://colab.research.google.com/github/Shikhas/Natural-Language-Processing/blob/master/Classify_long_text_longformer_lower_acc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Using Simple Transformer**

# %%
# !pip install simpletransformers

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import pandas as pd
import logging

# %%
logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# 1 -> Agriculture 
# 0 -> Transport
# 2 -> Taxation

#use_auth_token=True
# Preparing train data
train_data = [
    ["The objective of this Agreement, consistent with the Parties’ common commitment to the sustainable management of all types of forest, is to provide a legal framework aimed at ensuring that all imports into the Union from Viet Nam of timber and timber products covered by this Agreement have been legally produced and, in doing so, to promote trade in timber products that are from sustainably managed forests and harvested in accordance with the domestic legislation in the country of harvest.", 1],
    ["The air carriers of each Party shall have the right to freely establish offices and facilities in the territory of the other Party required for the provision of air transport and for the promotion and sale of air transport and related activities, including the right to sell and to issue any ticket and/or air waybill, both of its own and of any other air carrier.", 0],
    ["Interest payments made on debt-claims issued by debtors who are residents of Switzerland or pertaining to permanent establishments of non-residents located in Switzerland shall be excluded from the retention. For the purposes of this Agreement, the term permanent establishment shall have the meaning that it has under the relevant double taxation convention between Switzerland and the State of residence of the debtor. In the absence of such a convention, the term permanent establishment means a fixed place of business through which the business of a debtor is wholly or partly carried on.", 2],
]
train_df = pd.DataFrame(train_data)
train_df.columns = ["text", "labels"]

# Preparing eval data
eval_data = [
    ["To promote technical cooperation and research and development in the olive sector by encouraging the cooperation of public or private bodies and/or entities, whether national or international", 1],
    ["Air services agreements between the Republic of Korea and Member States of the European Union, as they may have been amended, modified or supplemented, which, at the date of the signature of this Agreement, have been signed and entered into force", 0],
    ["MIf interest received by a beneficial owner has been subject to taxes and retentions other than as provided for in this Agreement and the Member State of residence for tax purposes grants a tax credit for such taxes and retentions in accordance with its national law or double taxation conventions, such other taxes and retentions shall be credited before the procedure in paragraph 1 is applied.", 2],]
eval_df = pd.DataFrame(eval_data)
eval_df.columns = ["text", "labels"]

# Optional model configuration
model_args = ClassificationArgs(num_train_epochs=1)

# Create a ClassificationModel
model = ClassificationModel(
    'longformer',
    'allenai/longformer-base-4096',
    num_labels=3,
    args=model_args,
    use_cuda=False
) 

# Train the model
model.train_model(train_df)

# Evaluate the model
result, model_outputs, wrong_predictions = model.eval_model(eval_df)

# Make predictions with the model
predictions, raw_outputs = model.predict(["To enhance the role of the International Olive Council as a world documentation and information centre about the olive tree and its products and as a meeting point for all the operators in the sector"])



print(predictions)
print(raw_outputs)
# Out:
# Downloading:   0%|          | 0.00/694 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570M [00:00<?, ?B/s]
# Some weights of the model checkpoint at allenai/longformer-base-4096 were not used when initializing LongformerForSequenceClassification: ['lm_head.dense.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing LongformerForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
 # Add this result, model_outputs, wrong_predictions = model.eval_model(eval_df, f1=f1_multiclass, acc=accuracy_score)
# to get acc/accuracy, take more sentences in dataframe and more in eval and test -> use 80, 20, 20 rule

# %%
logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# 1 -> Agriculture 
# 0 -> Transport
# 2 -> Taxation

#use_auth_token=True
# Preparing train data
train_data = [
    ["The objective of this Agreement, consistent with the Parties’ common commitment to the sustainable management of all types of forest, is to provide a legal framework aimed at ensuring that all imports into the Union from Viet Nam of timber and timber products covered by this Agreement have been legally produced and, in doing so, to promote trade in timber products that are from sustainably managed forests and harvested in accordance with the domestic legislation in the country of harvest.", 1],
    ["The air carriers of each Party shall have the right to freely establish offices and facilities in the territory of the other Party required for the provision of air transport and for the promotion and sale of air transport and related activities, including the right to sell and to issue any ticket and/or air waybill, both of its own and of any other air carrier.", 0],
    ["Interest payments made on debt-claims issued by debtors who are residents of Switzerland or pertaining to permanent establishments of non-residents located in Switzerland shall be excluded from the retention. For the purposes of this Agreement, the term permanent establishment shall have the meaning that it has under the relevant double taxation convention between Switzerland and the State of residence of the debtor. In the absence of such a convention, the term permanent establishment means a fixed place of business through which the business of a debtor is wholly or partly carried on.", 2],
]
train_df = pd.DataFrame(train_data)
train_df.columns = ["text", "labels"]

# Preparing eval data
eval_data = [
    ["To promote technical cooperation and research and development in the olive sector by encouraging the cooperation of public or private bodies and/or entities, whether national or international", 1],
    ["Air services agreements between the Republic of Korea and Member States of the European Union, as they may have been amended, modified or supplemented, which, at the date of the signature of this Agreement, have been signed and entered into force", 0],
    ["MIf interest received by a beneficial owner has been subject to taxes and retentions other than as provided for in this Agreement and the Member State of residence for tax purposes grants a tax credit for such taxes and retentions in accordance with its national law or double taxation conventions, such other taxes and retentions shall be credited before the procedure in paragraph 1 is applied.", 2],]
eval_df = pd.DataFrame(eval_data)
eval_df.columns = ["text", "labels"]

# Optional model configuration
model_args = ClassificationArgs(num_train_epochs=1)

# Create a ClassificationModel
model = ClassificationModel(
    'longformer',
    'allenai/longformer-base-4096',
    num_labels=3,
    args=model_args,
    use_cuda=False
) 

# Train the model
model.train_model(train_df)

# Evaluate the model
result, model_outputs, wrong_predictions = model.eval_model(eval_df, f1=f1_multiclass, acc=accuracy_score)

# Make predictions with the model
predictions, raw_outputs = model.predict(["To enhance the role of the International Olive Council as a world documentation and information centre about the olive tree and its products and as a meeting point for all the operators in the sector"])



print(predictions)
print(raw_outputs)
# Out:
# Some weights of the model checkpoint at allenai/longformer-base-4096 were not used when initializing LongformerForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.bias']
# - This IS expected if you are initializing LongformerForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from sklearn.metrics import f1_score, accuracy_score


def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average='micro')

# %%
result, model_outputs, wrong_predictions = model.eval_model(eval_df, acc=accuracy_score)
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_longformer_128_3_2
# Running Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.0, 'acc': 0.3333333333333333, 'eval_loss': 1.0916506052017212}
